# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelacrestana/yolo-learning/blob/develop/basic_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.1/107.7 GB disk)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 130MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 413.1ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 307.6ms
# Speed: 2.6ms pre-process, 360.4ms inference, 19.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
import os

# Acessando diretorio onde estao as imagens geradas pelo modelo
# %cd runs/detect/exp
# Listar arquivos do diretório
# %ls
# Out:
# /content/yolov5/runs/detect/exp
# bus.jpg  zidane.jpg

# %%
from IPython.display import Image, display

# Exibir imagem
display(Image(filename="bus.jpg", width=450))
display(Image(filename="zidane.jpg", width=450))
